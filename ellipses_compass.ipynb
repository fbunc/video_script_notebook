# %% [markdown]
# # Derivation of an expression for an Ellipse using complex numbers
#
#
#
# $$\left(\frac{x}{x_o}\right)^2+\left(\frac{y}{y_o}\right)^2=1$$
#
# $$x_t=x_o \cos{t}$$
#
# $$y_t=y_o \sin{t}$$
#
# $$z_t=x_t+iy_t$$
#
# $$z_t=x_o \cos{t}+iy_o \sin{t}$$
#
# $$z_t=x_o\frac{e^{it}+e^{-it}}{2}+iy_o \frac{e^{it}-e^{-it}}{2i}$$
#
# $$z_t=x_o\frac{e^{it}+e^{-it}}{2}+iy_o \frac{e^{it}-e^{-it}}{2i}$$
#
# $$z_t=x_o\frac{e^{it}+e^{-it}}{2}+y_o \frac{e^{it}-e^{-it}}{2}$$
#
# $$z_t=x_o\frac{e^{it}}{2}+x_o\frac{e^{-it}}{2}+y_o \frac{e^{it}}{2}-y_o \frac{e^{-it}}{2}$$
#
# $$z_t=\frac{x_o+y_o}{2} e^{it} + \frac{x_o-y_o}{2} e^{-it}$$
#
# $$z_t= R_{_+} e^{it} +R_{_-} e^{-it}$$
#
# Assuming $x_o \geq y_o$ the foci  $F_1$ and $F_2$ are:
#
#
#
# $$F_{_1}=\sqrt{x_o^2-y_o^2}$$
#
# $$F_{_2}=-F_{_1}$$
#
# Or in terms of $R_{_+}$ and $R_{_-}$ :
#
# $$F_{_1}=2\sqrt{R_{_+}R_{_-}}$$
#
# Given that:
#
# $$\sqrt{R_{_+}R_{_-}}=\sqrt{\frac{(x_o+y_o)}{2}\frac{(x_o-y_o)}{2}}$$
#
# $$\sqrt{R_{_+}R_{_-}}=\sqrt{\frac{x_o^2-y_o^2}{4}}$$
#
# $$2\sqrt{R_{_+}R_{_-}}=\sqrt{x_o^2-y_o^2}$$
#
# ## General Oval expression used in Tau planet:
#
# With $z_o,R_{_+},R_{_-},F_{\pm} \in \mathbb{C}$
#
# $$z_t= z_o+R_{_+} e^{it} +R_{_-} e^{-it}$$
#
# $$F_{\pm}=\pm 2\sqrt{R_{_+}R_{_-}}$$
# $$F_{-}=-F_{+}$$
#
#
#
# ### Comparing to our classical ellipse expression
#
# * We have an ellipse only when certain conditions are met. For example assuming $x_o>y_o we have
#
# $$\left(\frac{x}{x_o}\right)^2+\left(\frac{y}{y_o}\right)^2=1$$
#
# $$R_{_+}=\frac{x_o+y_o}{2}$$
#
# $$R_{_-}=\frac{x_o-y_o}{2}$$
#
#
# $$F_{\pm}=\pm 2\sqrt{R_{_+}R_{_-}}$$
#
# * We have a circumference when $R_{_-}=0$
#
#
#
# ### Extra
#
#
# $$\frac{F_{+}}{2}=\sqrt{R_{_+}R_{_-}}$$
#
# $$\frac{F_{+}^2}{4}=R_{_+}R_{_-}$$
#
# $$R_{_-}=\frac{F_{+}^2}{4R_{_+}}$$
#
# $$\frac{F_{-}}{2}=-\sqrt{R_{_+}R_{_-}}$$
#
# $$\frac{F_{-}^2}{4}=R_{_+}R_{_-}$$
#
# $$R_{_+}=\frac{F_{-}^2}{4R_{_-}}$$
#
# $$R_{_+}=\frac{F_{-}^2}{4R_{_-}\frac{F_{+}^2}{4R_{_+}}}$$
#
# $$1=\frac{F_{-}^2}{R_{_-}F_{+}^2}$$

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams.update({
        "lines.color": "black",
        "patch.edgecolor": "white",
        "text.color": "white",
        "axes.facecolor": "black",
        "axes.edgecolor": "black",
        "axes.labelcolor": "black",
        "xtick.color": "white",
        "ytick.color": "white",
        "grid.color": "gray",
        "figure.facecolor": "black",
        "figure.edgecolor": "black",
        "savefig.facecolor": "black",
        "savefig.edgecolor": "black"})

# %%
t=np.linspace(0,2*np.pi,100)
x_o=2
y_o=1
f1 = np.sqrt(x_o**2 - y_o**2)
f2 = -np.sqrt(x_o**2 - y_o**2)
sx=14
sy=10
R_p=(x_o+y_o)/2
R_n=(x_o-y_o)/2
P_t=R_p*np.exp(1j*t)
N_t=R_n*np.exp(-1j*t)
z_t=P_t+N_t
plt.figure(figsize=(sx,sy))
plt.plot([z_t.real[20],f1],[z_t.imag[20],0],c='r')
plt.plot([z_t.real[20],f2],[z_t.imag[20],0],c='b')
plt.text(0,0,"$\\Theta$")
plt.scatter(np.sqrt(x_o**2-y_o**2),0,color="white")
plt.text(np.sqrt(x_o**2-y_o**2),0,"$F_1=\\sqrt{x_o^2-y_o^2}$")
plt.scatter(-np.sqrt(x_o**2-y_o**2),0,color="white")
plt.text(-np.sqrt(x_o**2-y_o**2),0,"$F_2=-\\sqrt{x_o^2-y_o^2}$")

plt.text(0.28,0.28,"$\\frac{x_o-y_o}{2} e^{-it}$")
plt.text(1,1,"$\\frac{x_o+y_o}{2} e^{it}$")
plt.text(1.4,0.7,"$\\frac{x_o+y_o}{2} e^{it}+\\frac{x_o-y_o}{2} e^{-it}$")
plt.scatter(z_t.real,z_t.imag,cmap='hsv',c=np.angle(-zz_t))
plt.scatter(P_t.real,P_t.imag,cmap='hsv',c=np.angle(-P_t))
plt.scatter(N_t.real,N_t.imag,cmap='hsv',c=np.angle(-P_t))

# %% [markdown]
# ## Let's check if the Foci work as expected
#
# The idea is that not every oval is an ellipse.

# %%
dist_f1_zt      = np.zeros_like(z_t,dtype='float')
dist_f2_zt      = np.zeros_like(z_t,dtype='float')
conserved_dist  = np.zeros_like(z_t,dtype='float')
for n in np.arange(z_t.size):
    dist_f1_zt[n]=np.abs(z_t[n]-f1)
    dist_f2_zt[n]=np.abs(z_t[n]-f2)
    conserved_dist[n]=dist_f1_zt[n]+dist_f2_zt[n]

# %%
conserved_dist
# Out:
# array([4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4.,
#        4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4.,
#        4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4.,
#        4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4.,
#        4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4.,
#        4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4.])

# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.linspace(0, 2*np.pi, 100)
x_o = 2
y_o = 1
sx = 14
sy = 10
R_p = (x_o + y_o) / 2
R_n = (x_o - y_o) / 2
P_t = R_p * np.exp(1j * t)
N_t = R_n * np.exp(-1j * t)
z_t = P_t + N_t

f1 = np.sqrt(x_o**2 - y_o**2)
f2 = -np.sqrt(x_o**2 - y_o**2)

dist_f1_zt = np.zeros_like(z_t, dtype='float')
dist_f2_zt = np.zeros_like(z_t, dtype='float')
conserved_dist = np.zeros_like(z_t, dtype='float')

for n in np.arange(z_t.size):
    dist_f1_zt[n] = np.abs(z_t[n] - f1)
    dist_f2_zt[n] = np.abs(z_t[n] - f2)
    conserved_dist[n] = dist_f1_zt[n] + dist_f2_zt[n]

# Plotting the arrays
plt.figure(figsize=(sx, sy))
plt.subplot(131)
plt.plot(dist_f1_zt, label='Distance $F_1$ to z_t')
plt.title('Distance from $F_1$ to z_t')
plt.legend()

plt.subplot(132)
plt.plot(dist_f2_zt, label='Distance $F_2$ to z_t')
plt.title('Distance from $F_2$ to z_t')
plt.legend()

plt.subplot(133)
plt.plot(conserved_dist, label='Conserved distance')
plt.title('Conserved distance')
plt.legend()

plt.tight_layout()
plt.show()

# %%
t=np.linspace(0,2*np.pi,100)
x_o=1+1j*1
y_o=2+1j*2

sx=16
sy=9
R_p=(x_o+y_o)/2
R_n=(x_o-y_o)/2
f1 = 2*np.sqrt(R_p*R_n)
f2 = -2*np.sqrt(R_p*R_n)


P_t=R_p*np.exp(1j*t)
N_t=R_n*np.exp(-1j*t)
z_t=P_t+N_t
plt.figure(figsize=(sx,sy))
plt.axis('equal')
plt.plot([z_t.real[30],f1.real],[z_t.imag[30],f1.imag],c='r')
plt.plot([z_t.real[30],f2.real],[z_t.imag[30],f2.imag],c='b')
plt.scatter(0,0,color="white")
plt.text(0,0,"$\\Theta$")
plt.scatter(f1.real,f1.imag,color="white")
plt.text(f1.real,f1.imag,"$F_1=2 \\sqrt{R_+ R_-}$")
plt.scatter(f2.real,f2.imag,color="white")
plt.text(f2.real,f2.imag,"$F_2=-2 \\sqrt{R_+ R_-}$")

plt.text(0.28,0.28,"$R_- e^{-it}$")
plt.text(1.1,1.9,"$R_+ e^{it}$")
plt.text(0.7,0.7,"$R_+ e^{it}+R_- e^{-it}$")
plt.scatter(z_t.real,z_t.imag,cmap='hsv',c=np.angle(-z_t),alpha=0.3)
plt.scatter(P_t.real,P_t.imag,cmap='hsv',c=np.angle(-P_t),alpha=0.3)
plt.scatter(N_t.real,N_t.imag,cmap='hsv',c=np.angle(-P_t),alpha=0.3)

# %%
N=3600
sample=int(0.3*N)
t=np.linspace(0,2*np.pi,N)
# x_o=3+1j*0
# y_o=1+1j*0

sx=16
sy=9
R_p=np.exp(1j*2*np.pi/3)
R_n=0.2*R_p
omega_p=1
omega_n=1
f1 = 2*np.sqrt(R_p*R_n)
f2 = -2*np.sqrt(R_p*R_n)


P_t=R_p*np.exp(1j*omega_p*t)
N_t=R_n*np.exp(-1j*omega_n*t)
z_t=P_t+N_t
plt.figure(figsize=(sx,sy))
plt.axis('equal')
plt.scatter(z_t.real,z_t.imag,cmap='hsv',c=np.angle(-P_t),alpha=0.3)
plt.scatter(P_t.real,P_t.imag,cmap='hsv',c=np.angle(-P_t),alpha=0.1)
plt.scatter(N_t.real,N_t.imag,cmap='hsv',c=np.angle(-P_t),alpha=0.1)
plt.scatter(f1.real,f1.imag,color="white")
plt.scatter(f2.real,f2.imag,color="white")
plt.plot([z_t.real[sample],f1.real],[z_t.imag[sample],f1.imag],c='r')
plt.plot([z_t.real[sample],f2.real],[z_t.imag[sample],f2.imag],c='b')
plt.scatter(0,0,c="red")

# %%
dist_f1_zt      = np.zeros_like(z_t,dtype='float')
dist_f2_zt      = np.zeros_like(z_t,dtype='float')
conserved_dist  = np.zeros_like(z_t,dtype='float')
for n in np.arange(z_t.size):
    dist_f1_zt[n]=np.abs(z_t[n]-f1)
    dist_f2_zt[n]=np.abs(z_t[n]-f2)
    conserved_dist[n]=dist_f1_zt[n]+dist_f2_zt[n]

# Plotting the arrays
plt.figure(figsize=(sx, sy))
plt.subplot(131)
plt.plot(t/(2*np.pi),dist_f1_zt, label='Distance $F_1$ to z_t')
plt.title('Distance from $F_1$ to z_t')
plt.legend()

plt.subplot(132)
plt.plot(t/(2*np.pi),dist_f2_zt, label='Distance $F_2$ to z_t')
plt.title('Distance from $F_2$ to z_t')
plt.legend()

plt.subplot(133)
plt.plot(t/(2*np.pi),conserved_dist, label='Total')
plt.title('Total')
plt.legend()

plt.tight_layout()
plt.show()

# %%
f1
# Out:
# (2.8284271247461903+0j)

# %%
import compass_functions as cf
